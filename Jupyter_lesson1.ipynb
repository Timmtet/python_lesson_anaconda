# %%
print(2)
# Out:
# 2

# %% [markdown]
# print("Hello world")

# %%
print("jwjw")
# Out:
# jwjw

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(2*8)
# Out:
# 16

# %% [markdown]
# # Header 1
# ## Header 2
# ### Header 3

# %% [markdown]
# *Togetherness*

# %%
# %%timeit
print(208*8)
# Out:
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# 1664
# ...

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON
